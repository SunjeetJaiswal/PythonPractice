# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/sunjeetjaiswal/Desktop/PythonPractice'

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %% [markdown]
# movies.columns

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', \
       'BudgetMillion', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion         Year
# count    559.000000      559.000000     559.000000   559.000000
# mean      47.309481       58.744186      50.236136  2009.152057
# std       26.413091       16.826887      48.731817     1.362632
# min        0.000000        0.000000       0.000000  2007.000000
# 25%       25.000000       47.000000      20.000000  2008.000000
# 50%       46.000000       58.000000      35.000000  2009.000000
# 75%       70.000000       72.000000      65.000000  2010.000000
# max       97.000000       96.000000     300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Jointplots

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', size = 10)

# %%
sns.set_style("darkgrid")
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', size = 10, kind='hex')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', size = 10, kind='reg')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', size = 10, kind='kde')

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#Histograms

# %%
m1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
m1 = sns.distplot(movies.CriticRating, bins = 15)

# %%
sns.set_style("darkgrid")
n1 = plt.hist(movies.CriticRating, bins = 15)

# %%
sns.set_style("darkgrid")
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
#movies.Genre =='Drama'
#movies[movies.Genre =='Drama'].BudgetMillion
plt.hist(movies[movies.Genre =='Drama'].BudgetMillion)
plt.show()

# %%
plt.hist([movies[movies.Genre =='Drama'].BudgetMillion, \
         movies[movies.Genre =='Action'].BudgetMillion, \
         movies[movies.Genre =='Thriller'].BudgetMillion], bins =15, stacked =True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 =list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre ==gen].BudgetMillion)
    mylabels.append(gen)

h=plt.hist(list1, bins = 30, stacked =True, rwidth = 1, label =mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#KDE Plot

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y ='AudienceRating', \
                  hue = 'Genre', fit_reg = False, \
                 size = 10)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, size =10)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# Working with Subplots()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating)

# %%
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating)

# %%
f,axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax =axes[0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[1])

# %%
f,axes = plt.subplots(2,2, figsize=(12,6), sharex=True)
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax =axes[0,1])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[1,1])

k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ---

# %%
#ViolinPlots

# %%
z=sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
z=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#Creating a Facet Grid

# %%
#g = sns.FacetGrid(movies, row='Genre', hue='Genre')
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist , 'CriticRating', 'AudienceRating')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-8b7fd31f5cd1> in <module>()
#       1 g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
# ----> 2 g = g.map(plt.hist , 'CriticRating', 'AudienceRating')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     729
#     730             # Draw the plot
# --> 731             self._facet_plot(func, ax, plot_args, kwargs)
#     732
#     733         # Finalize the annotations and layout
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     813
#     814         # Draw the plot
# --> 815         func(*plot_args, **plot_kwargs)
#     816
#     817         # Sort out the supporting information
#
# ...
